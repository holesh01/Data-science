# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
house=pd.read_csv("train.csv");

# %%
house.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
house.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 77 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   LotShape       1460 non-null   object
#  7   LandContour    1460 non-null   object
#  8   Utilities      1460 non-null   object
#  9   LotConfig      1460 non-null   object
#  10  LandSlope      1460 non-null   object
#  11  Neighborhood   1460 non-null   object
#  12  Condition1     1460 non-null   object
#  13  Condition2     1460 non-null   object
#  14  BldgType       1460 non-null   object
#  15  HouseStyle     1460 non-null   object
#  16  OverallQual    1460 non-null   int64
# ...

# %%
house.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000  ...
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726  ...
# std       1.112799    30.202904     20.645407   181.066207   456.098091  ...
# ...

# %%
sns.heatmap(house.isnull(),cbar=False,yticklabels=False,cmap='viridis')
# Out:
# <AxesSubplot:>

# %%
house.drop(['Alley','PoolQC','Fence','MiscFeature'],axis=1,inplace=True)

# %%
sns.heatmap(house.isnull(),cbar=False,yticklabels=False,cmap='viridis')
# Out:
# <AxesSubplot:>

# %%
house.MSZoning.value_counts()
# Out:
# RL         1151
# RM          218
# FV           65
# RH           16
# C (all)      10
# Name: MSZoning, dtype: int64

# %%
mszoning=pd.get_dummies(house['MSZoning'],drop_first=True)

# %%
house=pd.concat([house,mszoning],axis=1)

# %%
house
# Out:
#         Id  MSSubClass  LotFrontage  LotArea Street LotShape LandContour  \
# 0        1          60         65.0     8450   Pave      Reg         Lvl
# 1        2          20         80.0     9600   Pave      Reg         Lvl
# 2        3          60         68.0    11250   Pave      IR1         Lvl
# 3        4          70         60.0     9550   Pave      IR1         Lvl
# 4        5          60         84.0    14260   Pave      IR1         Lvl
# ...    ...         ...          ...      ...    ...      ...         ...
# 1455  1456          60         62.0     7917   Pave      Reg         Lvl
# 1456  1457          20         85.0    13175   Pave      Reg         Lvl
# 1457  1458          70         66.0     9042   Pave      Reg         Lvl
# 1458  1459          20         68.0     9717   Pave      Reg         Lvl
# 1459  1460          20         75.0     9937   Pave      Reg         Lvl
#
#      Utilities LotConfig LandSlope  ... MiscVal MoSold YrSold SaleType  \
# ...

# %%
house.drop(['MSZoning'],axis=1,inplace=True)

# %%
sns.boxplot(x='RL',y='LotFrontage',data=house)
# Out:
# <AxesSubplot:xlabel='RL', ylabel='LotFrontage'>

# %%
def add_LotFrontage(x):
    if(pd.isnull(x[0])):
        if(x[1]==0):
            return 57

        else :
            return 75
    else:
        return x[0]

# %%
house['LotFrontage']=house[['LotFrontage','RL']].apply(add_LotFrontage,axis=1)

# %%
sns.heatmap(house.isnull(),cbar=False,yticklabels=False,cmap='viridis')
# Out:
# <AxesSubplot:>

# %%
house.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 80 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   LotFrontage    1460 non-null   float64
#  3   LotArea        1460 non-null   int64
#  4   Street         1460 non-null   object
#  5   LotShape       1460 non-null   object
#  6   LandContour    1460 non-null   object
#  7   Utilities      1460 non-null   object
#  8   LotConfig      1460 non-null   object
#  9   LandSlope      1460 non-null   object
#  10  Neighborhood   1460 non-null   object
#  11  Condition1     1460 non-null   object
#  12  Condition2     1460 non-null   object
#  13  BldgType       1460 non-null   object
#  14  HouseStyle     1460 non-null   object
#  15  OverallQual    1460 non-null   int64
#  16  OverallCond    1460 non-null   int64
# ...

# %%
house.drop(['FireplaceQu'],axis=1,inplace=True)

# %%
sns.heatmap(house.isnull(),cbar=False,yticklabels=False,cmap='viridis')
# Out:
# <AxesSubplot:>

# %%
house.dropna(inplace=True)

# %%
sns.heatmap(house.isnull(),cbar=False,yticklabels=False,cmap='viridis')
# Out:
# <AxesSubplot:>

# %%
house.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1338 entries, 0 to 1459
# Data columns (total 79 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1338 non-null   int64
#  1   MSSubClass     1338 non-null   int64
#  2   LotFrontage    1338 non-null   float64
#  3   LotArea        1338 non-null   int64
#  4   Street         1338 non-null   object
#  5   LotShape       1338 non-null   object
#  6   LandContour    1338 non-null   object
#  7   Utilities      1338 non-null   object
#  8   LotConfig      1338 non-null   object
#  9   LandSlope      1338 non-null   object
#  10  Neighborhood   1338 non-null   object
#  11  Condition1     1338 non-null   object
#  12  Condition2     1338 non-null   object
#  13  BldgType       1338 non-null   object
#  14  HouseStyle     1338 non-null   object
#  15  OverallQual    1338 non-null   int64
#  16  OverallCond    1338 non-null   int64
# ...

# %%
w4=pd.get_dummies(house['LandContour'],drop_first=True)
s1=pd.get_dummies(house['LotShape'],drop_first=True)
s2=pd.get_dummies(house['Utilities'],drop_first=True)
s3=pd.get_dummies(house['LotConfig'],drop_first=True)
s4=pd.get_dummies(house['LandSlope'],drop_first=True)
s6=pd.get_dummies(house['Neighborhood'],drop_first=True)
a1=pd.get_dummies(house['Condition1'],drop_first=True)
a2=pd.get_dummies(house['Condition2'],drop_first=True)
a3=pd.get_dummies(house['BldgType'],drop_first=True)
a4=pd.get_dummies(house['HouseStyle'],drop_first=True)
a5=pd.get_dummies(house['RoofStyle'],drop_first=True)
q1=pd.get_dummies(house['Exterior1st'],drop_first=True)
q2=pd.get_dummies(house['ExterCond'],drop_first=True)
q3=pd.get_dummies(house['Foundation'],drop_first=True)
q4=pd.get_dummies(house['Heating'],drop_first=True)
w1=pd.get_dummies(house['GarageCond'],drop_first=True)
w2=pd.get_dummies(house['SaleCondition'],drop_first=True)
w3=pd.get_dummies(house['SaleType'],drop_first=True)

# %%
house=pd.concat([house,s1,s2,s3,s4,s6,a1,a2,a3,a4,a5,q1,q2,q3,w1,w2,w3,w4],axis=1)

# %%
house.columns
# Out:
# Index(['Id', 'MSSubClass', 'LotFrontage', 'LotArea', 'LotShape', 'LandContour',
#        'Utilities', 'LotConfig', 'LandSlope', 'Neighborhood',
#        ...
#        'Con', 'ConLD', 'ConLI', 'ConLw', 'New', 'Oth', 'WD', 'HLS', 'Low',
#        'Lvl'],
#       dtype='object', length=184)

# %%
house.drop(['LotFrontage', 'LotArea', 'LotShape', 'LandContour','Utilities', 'LotConfig', 'LandSlope', 'Neighborhood','Condition2','Condition1','BldgType','HouseStyle','RoofStyle','Exterior1st','ExterCond','Foundation','Heating','GarageCond','saleCondition','SaleType'],axis=1,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/79/99425rgx20g5h19829rqr72w0000gn/T/ipykernel_56767/2815115322.py in <module>
# ----> 1 house.drop(['LotFrontage', 'LotArea', 'LotShape', 'LandContour','Utilities', 'LotConfig', 'LandSlope', 'Neighborhood','Condition2','Condition1','BldgType','HouseStyle','RoofStyle','Exterior1st','ExterCond','Foundation','Heating','GarageCond','saleCondition','SaleType'],axis=1,inplace=True)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
# ...

# %%
house.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1338 entries, 0 to 1459
# Columns: 184 entries, Id to Lvl
# dtypes: float64(3), int64(35), object(36), uint8(110)
# memory usage: 927.7+ KB
